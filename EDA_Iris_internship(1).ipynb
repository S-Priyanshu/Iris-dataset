# %% [markdown]
# <a href="https://colab.research.google.com/github/S-Priyanshu/Iris-dataset/blob/main/EDA_Iris_internship(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Imported libraries for data analysis and visualization in Python
#
#
# 1.  Pandas is a powerful data manipulation and analysis library, providing data structures like DataFrames that are useful for working with structured data
# 2.   NumPy is a numerical computing library in Python that provides support for large, multi-dimensional arrays and matrices, along with mathematical functions to operate on these arrays.
# 3.   Matplotlib is a widely-used plotting library in Python. The pyplot module provides a simple interface for creating various types of plots and visualizations.
# 4. Seaborn library, which is built on top of Matplotlib and provides a high-level interface for drawing attractive and informative statistical graphics.
# 5.Import the warnings module, which provides a mechanism to issue warning messages from a Python program. It can be used to filter or ignore specific warning messages.

# %%
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Iris dataset is loaded into a Pandas DataFrame
# and the head part of the dataset is called

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# complete Iris dataset is called

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# This function is used to count the occurrences of unique values in a categorical variable.
# This output shows that there are 50 instances of each species in the Iris dataset.

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# It represents the dimensions of the DataFrame.
# First element of the tuple is the number of rows(150), and the second element is the number of columns(5).

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# It gives the name of the colums of the dataset .

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Thismethod in Pandas is used to print a concise summary of a DataFrame, including information about the data types (float64(4), object(1)), non-null values, and memory usage. When you execute df.info, it provides details about the structure and content of the DataFrame.

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# This method in Pandas is used to check for missing or null values in a DataFrame.The output will show the count of null values for each column in your DataFrame. If there are no null values, the count for each column will be zero.
# The output here shows that  that there are no missing values in any of the columns of your DataFrame (df). All columns have a count of zero null values.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# This method in Pandas is used to generate descriptive statistics of a DataFrame.
# It provides summary statistics for each numerical column in the DataFrame, including count, mean, standard deviation, minimum, 25th percentile (Q1), median (50th percentile or Q2), 75th percentile (Q3), and maximum.

# %% [markdown]
# # **PLOTS**

# %%
sns.countplot(x='species' , data=df)
plt.xlabel('species')
plt.ylabel('count')
plt.show()

# %% [markdown]
# This code will display a bar plot where each bar represents the count of occurrences for each unique species in the 'species' column of your DataFrame. The x-axis represents the species, and the y-axis represents the count.
# Here there is an count of setosa=50 ,versicolor =50 ,virginica =50

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='sepal_length', hue='species', palette='inferno')
plt.show()

# %% [markdown]
# Density of setosa is more on lower sepal_length and density ofvirginica is more on higher sepal_length

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='sepal_width', hue='species', palette='Reds')
plt.show()

# %% [markdown]
#  density setosa belongs to higher sepal width , versicolor belongs to lower sepal width and virginica belongs to medium sepal width

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='petal_length', hue='species', palette='inferno')
plt.show()

# %% [markdown]
# Density of setosa is more on lower petal_length and density ofvirginica is more on higher petal_length

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='petal_width', hue='species', palette='magma')
plt.show()

# %% [markdown]
# Density of setosa is more on lower petal_width and density ofvirginica is more on higher petal_width

# %% [markdown]
# conclusion -
#
# *    we can say that virginica are the flower with larger petal_length,larger petal_width ,medium sepal_width , larger sepal length
# *   setosa are the flower with lower petal_length,lower petal_width ,higher sepal_width , lower sepal length
# *   versicolor are the flower with medium petal_length,medium petal_width ,lower sepal_width , medium sepal length

# %% [markdown]
# # **HISTOGRAM**

# %%
plt.figure(figsize=(5,6))
sns.histplot(x='species' , data=df)
# Out:
# <Axes: xlabel='species', ylabel='Count'>

# %% [markdown]
# Basic histogram plot that shows the count of each species

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x="sepal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# histogram plot of sepal length.From this we can say that there are more than 25 flowers with sepal length of 6.0-6.5 and more the 25 species of sepal length between 5.5-6.0 .  The figure size to 10 inches in width and 6 inches in height.

# %%
plt.figure(figsize=(6,5))
sns.histplot(data=df, x="sepal_width")
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %% [markdown]
# histogram plot of sepal width and the count of sepal width .there are above 35 flowers with sepal width between 3.0

# %%
plt.figure(figsize=(6,5))
sns.histplot(data=df, x="petal_length")
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# this histogram shows the count of flowers with petal length . From this histogram we can also state that there are no plant with petal length between 2-3

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=df, x="petal_width")
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %% [markdown]
# this histogram shows the count of flowers with petal width . From this histogram we can also state that there are no plant with petal width between 0.5-1.0 . Also there is a cpount of above 40 plant with the petal width between 0.0-0.5

# %%
figure, ax = plt.subplots(2, 2, figsize=(8,8))

ax[0,0].set_title("sepal_length")
ax[0,0].hist(df['sepal_length'], bins=8)

ax[0,1].set_title("sepal_width")
ax[0,1].hist(df['sepal_width'], bins=6);

ax[1,0].set_title("petal_length")
ax[1,0].hist(df['petal_length'], bins=5);

ax[1,1].set_title("petal_width")
ax[1,1].hist(df['petal_width'], bins=5);

# %% [markdown]
# A 2x2 grid of subplots using plt.subplots(2, 2, figsize=(8, 8))
#
#
#
#
#
# * This code creates a 2x2 grid of subplots where each subplot corresponds to a different attribute (sepal_length, sepal_width, petal_length, petal_width), and a histogram is plotted for each attribute. hist() is used to create a histogram with 5 bins for the 'petal_width' data.
#
#
#
#
#
#
#
# 1.  Sepal length highest freq lies between 5.5 cm to 6 cm which is 30-35 cM
# 2.  Petal length highest freq lies between 1 cm to 2 cm which is 50 cm
# 3.  Sepal width highest freq lies between 3 cm to 3.5 cm which is 70 cm
# 4.  Petal width highest freq lies between 0 cm to 0.5 cm which is 40-45 cm

# %%
axis = df.plot.hist(bins=30, alpha=0.5)
axis.set_xlabel('Size in cm');

# %% [markdown]
# From the  graph we can see that sepalwidth is longer than any other feature followed by petalwidth

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='sepal_length', data=df, bins=20, kde=True)
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.show()

# %% [markdown]
# This code creates a histogram for the 'sepal_length' column with 20 bins and overlays a kernel density estimate (KDE) using Seaborn.

# %% [markdown]
# # **SCATTER PLOT**

# %%
sns.scatterplot(data=df,x='petal_length',y='sepal_width', hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_width'>

# %% [markdown]
# *   For SETOSA sepal width is greater than petal length
# *   For Virginica petal length is more than sepalwidth

# %%
sns.scatterplot(data=df,x='sepal_length',y='sepal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# Iris-virginica has a longer sepal length while Iris-setosa has larger sepal width.  For setosa sepal width is more than sepal length
#
#
#
# *  Species Setosa has smaller sepal lengths but larger sepal widths.
# Versicolor Species lies in the middle of the other two species in terms of sepal length and width
# Species Virginica has larger sepal lengths but smaller sepal widths.

# %%
sns.scatterplot(data=df,x='petal_length',y='petal_width', hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# *  For setosa petal length and petal width are small
# *  for virginica petal length ang petal width are larger

# %%
sns.scatterplot(data=df,x='sepal_length',y='petal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
ax = plt.axes()

ax.scatter(df.sepal_length, df.sepal_width)

# Label the axes
ax.set(xlabel='sepal_length',
       ylabel='sepal_width ',
       title='Sepal-length vs width');

# %% [markdown]
# # **BOX PLOT**

# %%
sns.boxplot(x='sepal_width', data=df)
# Out:
# <Axes: xlabel='sepal_width'>

# %% [markdown]
# A box plot is created using seaborn . A boxplot is a useful visualization for summarizing the distribution of a numerical variable, providing information about the median, quartiles, and potential outliers.
#
#
# *   x='sepal_width': Specifies the column for which you want to create the boxplot.
# *  The resulting boxplot will display a box that represents the interquartile range (IQR) between the first quartile (Q1) and the third quartile (Q3). The line inside the box represents the median. Whiskers extend to points within a certain distance of the interquartile range, and points beyond the whiskers are considered potential outliers.
#
# In the above graph, the values above 4 and below 2 are acting as outliers.

# %%
sns.boxplot(x='sepal_length', data=df)
# Out:
# <Axes: xlabel='sepal_length'>

# %% [markdown]
# x='sepal_length': Specifies the column for which you want to create the boxplot.
# In the above graph, the values above 8 and below 4.5 are acting as outliers . also can notice that there are no outliers here

# %%
sns.boxplot(x='petal_width', data=df)
# Out:
# <Axes: xlabel='petal_width'>

# %% [markdown]
# x='petal_width': Specifies the column for which you want to create the boxplot

# %%
sns.boxplot(x='petal_length', data=df)
# Out:
# <Axes: xlabel='petal_length'>

# %% [markdown]
# x='petal_length': Specifies the column for which you want to create the boxplot

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='species',y='sepal_width',data=df ,palette='YlGnBu')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# *   x='species': Specifies the categorical variable (species) for the x-axis.
# *   y='sepal_width': Specifies the numerical variable (sepal_width) for the y-axis.
# *   palette='YlGnBu': Specifies the color palette for the plot.
#
# The resulting boxplot  have box plots for each species(setosa,versicolor,virginica), showing the distribution of sepal widths within each species. The use of the YlGnBu color palette adds a sequential color scheme to the plot.
#
#
# - From the plot we can say that setosa species and virginica has outliers

# %%
def graph(y):
	sns.boxplot(x="species", y=y, data=df)

plt.figure(figsize=(10,10))


plt.subplot(221) #Specifies a 2x2 grid of subplots and selects the first subplot (top-left corner).
graph('sepal_length')

plt.subplot(222)  # Select the second subplot (top-right corner)
graph('sepal_width')

plt.subplot(223) # Select the third subplot (bottom-left corner)
graph('petal_length')

plt.subplot(224)   # Select the fourth subplot (bottom-right corner)
graph('petal_width')

plt.show()

# %% [markdown]
# *   Species Setosa has the smallest features and less distributed with some outliers.
# *   Species Versicolor has the average features.
#
# *   Species Virginica has the highest features

# %% [markdown]
# # **HEAP MAP**

# %%
# sns.heatmap(df.corr(), linecolor='white', linewidths=1)

sns.heatmap(df.drop('species', axis=1).corr(), linecolor='white', linewidths=1) # Drop the non-numeric column 'species' before calculating the correlation matrix.
# Out:
# <Axes: >

# %% [markdown]
# A heatmap is a graphical representation of data in a matrix form, where values are represented by colors.
#
#
#
# *  df.corr(): Computes the pairwise correlation matrix for numerical columns in the DataFrame.
# *   sns.heatmap(): Creates a heatmap using Seaborn, where the correlation values are represented by colors.
#
#
# *   linecolor='white': Sets the color of the lines between cells in the heatmap to white.
# *   linewidths=1: Sets the width of the lines between cells to 1.
#
# The heatmap allows you to visually assess the correlation between different numerical features. The colors and the corresponding values in the cells provide a quick overview of the strength and direction of the relationships between variables. Lighter colors typically indicate stronger correlations, while darker colors indicate weaker correlations.
#
#
#
# ***Updated****
#
# This line of code generates a heatmap to visualize the correlation matrix of the DataFrame df, after removing the species column. Here's a breakdown:
#
# df.drop('species', axis=1): This part removes the species column from the DataFrame df.
# drop(): This is a pandas function that removes specified rows or columns from a DataFrame.
# 'species': This is the name of the column to be removed.
# axis=1: This specifies that we want to drop a column. axis=0 would drop a row.
# .corr(): This calculates the correlation matrix of the remaining numeric columns in the DataFrame.
# sns.heatmap(...): This creates a heatmap using the seaborn library.
# linecolor='white': This sets the color of the lines separating the cells in the heatmap to white.
# linewidths=1: This sets the width of the lines separating the cells in the heatmap to 1.
# This code effectively visualizes the correlation between the numerical features of the dataset by excluding the non-numeric column that was causing the error.

# %%
sns.heatmap(df.drop('species', axis=1).corr(),cmap="YlGnBu", linecolor='white', linewidths=1)
# Out:
# <Axes: >

# %% [markdown]
# *   cmap="YlGnBu" parameter to the sns.heatmap() function, which specifies the color map to be used for the heatmap
#
#
#
#
# By specifying the color map, you can control the aesthetic appearance of the heatmap. Different color maps may be more suitable for different types of data or personal preferences. "YlGnBu" (yellow,Green ,Blue)is a popular choice for visualizing correlations as it provides a clear progression from low to high values with distinct color shades.

# %%
sns.heatmap(df.drop('species', axis=1).corr(), linecolor='white',linewidths=1, annot=True, fmt="f")
plt.show()

# %% [markdown]
# *   Petal width and petal length have high correlations.
# *   Petal length and sepal width have good correlations.
# *
# Petal Width and Sepal length have good correlations.
#
#
#
# *   annot=True: Enables the annotation of each cell with the numeric value.
# *  fmt="f": Specifies the format of the numeric values to be displayed. In this case, "f" stands for float format.
